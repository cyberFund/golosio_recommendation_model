# %%
import codecs
import logging, gensim, bz2
# logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
# Out:
# Using TensorFlow backend.

# %%
from gensim import corpora
dictionary = corpora.Dictionary.load('datasets/golos-corpora.dict')

# %%
from gensim import models
# tfidf = models.TfidfModel(corpus, id2word=dictionary, normalize=True)

mm_golos = corpora.MmCorpus('datasets/golos-corpora_bow.mm')
print(mm_golos)
# Out:
# MmCorpus(78506 documents, 101139 features, 5028549 non-zero entries)

# %%
lda_golos = models.ldamodel.LdaModel(corpus=mm_golos, id2word=dictionary, num_topics=100, update_every=1, chunksize=10000, passes=1)

# %%
lda_golos.print_topics()
# Out:
# [(9,
#   '0.021*"оптовик" + 0.019*"adwords" + 0.017*"утп" + 0.014*"инсайд" + 0.008*"который" + 0.007*"это" + 0.006*"год" + 0.006*"ученый" + 0.005*"исследование" + 0.005*"слайд"'),
#  (36,
#   '0.010*"fuente" + 0.007*"він" + 0.006*"україни" + 0.006*"але" + 0.005*"рок" + 0.005*"джереть" + 0.005*"то" + 0.004*"час" + 0.004*"якщо" + 0.004*"дуж"'),
#  (28,
#   '0.016*"заказ" + 0.014*"посадочный" + 0.011*"опт" + 0.009*"dsc" + 0.009*"выступление" + 0.007*"это" + 0.007*"ключевик" + 0.007*"новый" + 0.006*"200.000" + 0.006*"трек"'),
#  (63,
#   '0.018*"это" + 0.012*"файл" + 0.010*"программа" + 0.009*"сайт" + 0.009*"каталог" + 0.007*"функция" + 0.007*"который" + 0.005*"выбирать" + 0.005*"скриншот" + 0.005*"быть"'),
#  (2,
#   '0.017*"матч" + 0.011*"ребенок" + 0.009*"верстальщик" + 0.008*"это" + 0.007*"45000" + 0.006*"верстка" + 0.006*"стадион" + 0.006*"который" + 0.006*"📍" + 0.006*"свой"'),
#  (98,
#   '0.055*"ленд" + 0.013*"срм" + 0.011*"это" + 0.010*"💰" + 0.009*"который" + 0.008*"bc" + 0.007*"smi" + 0.006*"romel" + 0.005*"___" + 0.004*"tvorchestvo"'),
#  (50,
#   '0.126*"руб" + 0.033*"реклама" + 0.015*"точка" + 0.015*"рекламный" + 0.014*"000" + 0.013*"сайт" + 0.011*"запускать" + 0.010*"объявление" + 0.010*"проект" + 0.009*"неделя"'),
#  (88,
#   '0.062*"голос" + 0.060*"пост" + 0.020*"автор" + 0.020*"**" + 0.014*"комментарий" + 0.010*"спасибо" + 0.010*"выплата" + 0.010*"arcange" + 0.010*"пользователь" + 0.009*"свой"'),
#  (99,
#   '0.010*"это" + 0.006*"утро" + 0.005*"день" + 0.005*"все" + 0.004*"свой" + 0.004*"очень" + 0.004*"начинать" + 0.004*"машина" + 0.004*"сказать" + 0.004*"диана"'),
#  (26,
#   '0.118*"кит" + 0.018*"1000000" + 0.015*"dreamer" + 0.014*"lumia" + 0.007*"вызов" + 0.007*"рифма" + 0.006*"..." + 0.006*"11500" + 0.005*"караганда" + 0.005*"oleg257"'),
#  (60,
#   '0.017*"суд" + 0.008*"leylar" + 0.008*"b5" + 0.007*"нарушение" + 0.007*"судно" + 0.007*"дело" + 0.007*"боец" + 0.007*"который" + 0.006*"год" + 0.006*"экспертиза"'),
#  (21,
#   '0.015*"мес" + 0.009*"это" + 0.009*"человек" + 0.008*"тренировка" + 0.007*"который" + 0.006*"ребенок" + 0.005*"здоровье" + 0.005*"организм" + 0.005*"тело" + 0.004*"свой"'),
#  (31,
#   '0.043*"q" + 0.036*"2017г" + 0.024*"20separadora" + 0.020*"приседание" + 0.018*"p" + 0.015*"танец" + 0.011*"танго" + 0.010*"вокал" + 0.009*"жанна" + 0.009*"переть"'),
#  (78,
#   '0.032*"это" + 0.017*"человек" + 0.011*"жизнь" + 0.010*"который" + 0.007*"день" + 0.007*"очень" + 0.006*"делать" + 0.006*"свой" + 0.006*"понимать" + 0.005*"каждый"'),
#  (12,
#   '0.033*"1000р" + 0.012*"1млн" + 0.011*"десятка" + 0.010*"кострома" + 0.008*"1.03" + 0.008*"салют" + 0.008*"донбас" + 0.008*"могилев" + 0.007*"зарядка" + 0.007*"профи"'),
#  (4,
#   '0.035*"план" + 0.032*"сделать" + 0.019*"инсайт" + 0.015*"упаковка" + 0.013*"сегодня" + 0.013*"день" + 0.012*"встреча" + 0.011*"ниша" + 0.010*"разбор" + 0.010*"вопрос"'),
#  (92,
#   '0.384*"..." + 0.005*"все" + 0.005*".." + 0.005*"знать" + 0.004*"шеф" + 0.004*"." + 0.004*"еще" + 0.003*"это" + 0.003*"утро" + 0.003*"день"'),
#  (20,
#   '0.037*"год" + 0.007*"сша" + 0.006*"россия" + 0.006*"это" + 0.005*"который" + 0.004*"золото" + 0.004*"время" + 0.004*"ссср" + 0.004*"страна" + 0.004*"доллар"'),
#  (69,
#   '0.010*"the" + 0.007*"это" + 0.007*"tree" + 0.006*"икона" + 0.006*"friend" + 0.006*"credit" + 0.006*"call" + 0.005*"mountain" + 0.004*"and" + 0.004*"который"'),
#  (74,
#   '0.012*"неделя" + 0.012*"лэндинг" + 0.011*"тыс" + 0.010*"день" + 0.010*"средний" + 0.010*"прибыль" + 0.009*"месяц" + 0.008*"чек" + 0.008*"продажа" + 0.007*"это"')]

# %%
lda_golos.print_topics()
# Out:
# [(78,
#   '0.032*"это" + 0.017*"человек" + 0.011*"жизнь" + 0.010*"который" + 0.007*"день" + 0.007*"очень" + 0.006*"делать" + 0.006*"свой" + 0.006*"понимать" + 0.005*"каждый"'),
#  (2,
#   '0.017*"матч" + 0.011*"ребенок" + 0.009*"верстальщик" + 0.008*"это" + 0.007*"45000" + 0.006*"верстка" + 0.006*"стадион" + 0.006*"который" + 0.006*"📍" + 0.006*"свой"'),
#  (14,
#   '0.177*"лендинг" + 0.021*"сделать" + 0.012*"кол" + 0.012*"неделя" + 0.010*"пуля" + 0.009*"создавать" + 0.009*"паблик" + 0.008*"микроупаковка" + 0.007*"запускать" + 0.007*"это"'),
#  (58,
#   '0.022*"это" + 0.012*"день" + 0.010*"свой" + 0.010*"очень" + 0.010*"понимать" + 0.009*"сегодня" + 0.009*"все" + 0.009*"человек" + 0.008*"мой" + 0.008*"делать"'),
#  (65,
#   '0.040*"фильм" + 0.015*"это" + 0.011*"лэнд" + 0.010*"кино" + 0.008*"сценарий" + 0.007*"главный" + 0.007*"сцена" + 0.006*"актер" + 0.006*"который" + 0.006*"08.03"'),
#  (98,
#   '0.055*"ленд" + 0.013*"срм" + 0.011*"это" + 0.010*"💰" + 0.009*"который" + 0.008*"bc" + 0.007*"smi" + 0.006*"romel" + 0.005*"___" + 0.004*"tvorchestvo"'),
#  (29,
#   '0.032*"грн" + 0.014*"храм" + 0.011*"святой" + 0.009*"ср" + 0.009*"доделывать" + 0.008*"башня" + 0.008*"это" + 0.007*"который" + 0.007*"церковь" + 0.007*"стена"'),
#  (56,
#   '0.010*"это" + 0.009*"планерка" + 0.009*"мойка" + 0.006*"вытаскивание" + 0.005*"который" + 0.005*"складно" + 0.004*"человек" + 0.004*"свой" + 0.004*"голос" + 0.004*"вип"'),
#  (60,
#   '0.017*"суд" + 0.008*"leylar" + 0.008*"b5" + 0.007*"нарушение" + 0.007*"судно" + 0.007*"дело" + 0.007*"боец" + 0.007*"который" + 0.006*"год" + 0.006*"экспертиза"'),
#  (28,
#   '0.016*"заказ" + 0.014*"посадочный" + 0.011*"опт" + 0.009*"dsc" + 0.009*"выступление" + 0.007*"это" + 0.007*"ключевик" + 0.007*"новый" + 0.006*"200.000" + 0.006*"трек"'),
#  (43,
#   '0.009*"это" + 0.008*"который" + 0.005*"такой" + 0.004*"все" + 0.004*"свой" + 0.004*"девушка" + 0.004*"самый" + 0.004*"время" + 0.004*"место" + 0.004*"один"'),
#  (4,
#   '0.035*"план" + 0.032*"сделать" + 0.019*"инсайт" + 0.015*"упаковка" + 0.013*"сегодня" + 0.013*"день" + 0.012*"встреча" + 0.011*"ниша" + 0.010*"разбор" + 0.010*"вопрос"'),
#  (32,
#   '0.023*"дожимать" + 0.017*"это" + 0.009*"человек" + 0.008*"жизнь" + 0.007*"свой" + 0.006*"который" + 0.005*"такой" + 0.005*"мочь" + 0.003*"самый" + 0.003*"время"'),
#  (84,
#   '0.013*"город" + 0.008*"это" + 0.008*"год" + 0.007*"который" + 0.007*"место" + 0.007*"музей" + 0.005*"один" + 0.005*"самый" + 0.005*"отель" + 0.004*"время"'),
#  (50,
#   '0.126*"руб" + 0.033*"реклама" + 0.015*"точка" + 0.015*"рекламный" + 0.014*"000" + 0.013*"сайт" + 0.011*"запускать" + 0.010*"объявление" + 0.010*"проект" + 0.009*"неделя"'),
#  (68,
#   '0.056*"алекс" + 0.033*"06.03" + 0.021*"светильник" + 0.018*"март" + 0.016*"neo" + 0.015*"кремль" + 0.011*"астрахань" + 0.009*"матрас" + 0.009*"о" + 0.008*"новгород"'),
#  (67,
#   '0.030*"видос" + 0.011*"..." + 0.011*"дескриптор" + 0.007*"который" + 0.006*"это" + 0.006*"______" + 0.004*"противогаз" + 0.004*"редизайн" + 0.004*"6.5" + 0.003*"рейтинговый"'),
#  (45,
#   '0.041*"таргет" + 0.039*"картинка" + 0.017*"5b1" + 0.017*"5d" + 0.013*"таргетинг" + 0.011*"тестовый" + 0.008*"черновой" + 0.007*"загружать" + 0.006*"изображение" + 0.006*"это"'),
#  (99,
#   '0.010*"это" + 0.006*"утро" + 0.005*"день" + 0.005*"все" + 0.004*"свой" + 0.004*"очень" + 0.004*"начинать" + 0.004*"машина" + 0.004*"сказать" + 0.004*"диана"'),
#  (95,
#   '0.018*"подписчик" + 0.014*"видео" + 0.011*"пост" + 0.011*"ролик" + 0.009*"день" + 0.009*"контент" + 0.009*"аккаунт" + 0.008*"ютуб" + 0.007*"это" + 0.007*"мой"')]
